# %% [markdown]
#  1- Imposto a pagar no Lucro Presumido
#
# - 5% sobre faturamento de ISS (mensal)
# - 0,65% de PIS sobre faturamento, (mensal)
# - 3% de COFINS sobre faturmaneto, (mensal)
# - 4.8% de IR (trimestral)
# - 10% de IR Adicional sobre o que ultrapassar 20mil do faturamento (trimestral)
# - CSLL: 2,88% sobre faturamento (trimestral)

# %%
faturamento = {
    'jan': 'R$ 95.141,98',
    'fev': 'R$ 95.425,16',
    'mar': 'R$ 89.716,31',
    'abr': 'R$ 78.459,99',
    'mai': 'R$ 71.087,28',
    'jun': 'R$ 83.911,06',
    'jul': 'R$ 56.467,26',
    'ago': 'R$ 88.513,58',
    'set': 'R$ 66.552,49',
    'out': 'R$ 80.164,07',
    'nov': 'R$ 66.964,33',
    'dez': 'R$ 71.525,25',
}

# você precisa inserir no sistema um dicionário no formato:

# resultado = {
#     'mes': (faturamento, imposto_mensal, imposto_trimestral),
# }

# passo a passo do código.

# para cada mês de faturamento 
 #transformar o faturamento de mês para número.
 #calcular o imposto mensal 
# calcular o i posto trimestral 
#adicionar o faturamento, imposto mensal, imposto trimestral  no dicionário resultado.
 
def transformar_em_numero(texto):
    texto = texto.replace('R$', '')
    texto = texto.replace(' ', '')
    texto = texto.replace('.', '')
    texto = texto.replace(',', '.')
    return float(texto)

def calcular_imposto_mensal(valor_faturamento):
    iss = valor_faturamento * 0.05
    pis = valor_faturamento * 0.65
    cofins = valor_faturamento * 0.03
    imposto_mensal = iss + pis + cofins
    return imposto_mensal 

def calcular_imposto_trimestral(valor_faturamento):
   ir = valor_faturamento * 0.048
   csll = valor_faturamento * 2.88
   adicional_ir = 0
   if valor_faturamento >2000:
        adicional_ir = (valor_faturamento - 2000) * 0.1
   imposto_trimestral = ir + csll + adicional_ir
   return  imposto_trimestral

resultado = {}
for mes in faturamento:
    valor_faturamento = transformar_em_numero(faturamento[mes])
    imposto_mensal = calcular_imposto_mensal(valor_faturamento)
    imposto_trimestral = calcular_imposto_trimestral(valor_faturamento)
    resultado[mes]= (valor_faturamento, imposto_mensal, imposto_trimestral)
print(resultado)
# Out:
# {'jan': (95141.98, 69453.6454, 287889.91543999995), 'fev': (95425.16, 69660.3668, 288747.38448), 'mar': (89716.31, 65492.906299999995, 271460.98668), 'abr': (78459.99, 57275.792700000005, 237376.84972000003), 'mai': (71087.28, 51893.714400000004, 215052.28384), 'jun': (83911.06, 61255.0738, 253882.68967999998), 'jul': (56467.26, 41221.0998, 170782.86328), 'ago': (88513.58, 64614.913400000005, 267819.12024), 'set': (66552.49, 48583.3177, 201320.93972000002), 'out': (80164.07, 58519.77110000001, 242536.80396000002), 'nov': (66964.33, 48883.960900000005, 202567.99124), 'dez': (71525.25, 52213.432499999995, 216378.457)}

# %% [markdown]
# ### 2 - Puxando informações de um banco de Dados

# %%
# puxando informações SQL de um banco de dados
informacoes = [(1, 'NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 167411.18, 0.0, 400184.25, None, 567595.43, 567595.43, 2011, '', 'San Francisco', ''), (2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', 155966.02, 245131.88, 137811.38, None, 538909.28, 538909.28, 2011, '', 'San Francisco', ''), (3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', 212739.13, 106088.18, 16452.6, None, 335279.91, 335279.91, 2011, '', 'San Francisco', ''), (4, 'CHRISTOPHER CHONG', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 77916.0, 56120.71, 198306.9, None, 332343.61, 332343.61, 2011, '', 'San Francisco', ''), (5, 'PATRICK GARDNER', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 134401.6, 9737.0, 182234.59, None, 326373.19, 326373.19, 2011, '', 'San Francisco', ''), (6, 'DAVID SULLIVAN', 'ASSISTANT DEPUTY CHIEF II', 118602.0, 8601.0, 189082.74, None, 316285.74, 316285.74, 2011, '', 'San Francisco', ''), (7, 'ALSON LEE', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 92492.01, 89062.9, 134426.14, None, 315981.05, 315981.05, 2011, '', 'San Francisco', ''), (8, 'DAVID KUSHNER', 'DEPUTY DIRECTOR OF INVESTMENTS', 256576.96, 0.0, 51322.5, None, 307899.46, 307899.46, 2011, '', 'San Francisco', ''), (9, 'MICHAEL MORRIS', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 176932.64, 86362.68, 40132.23, None, 303427.55, 303427.55, 2011, '', 'San Francisco', ''), (10, 'JOANNE HAYES-WHITE', 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 285262.0, 0.0, 17115.73, None, 302377.73, 302377.73, 2011, '', 'San Francisco', '')]
descricao = (('Id', "<class 'int'>", None, 10, 10, 0, True), ('EmployeeName', "<class 'str'>", None, 65536, 65536, 0, True), ('JobTitle', "<class 'str'>", None, 65536, 65536, 0, True), ('BasePay', "<class 'float'>", None, 54, 54, 0, True), ('OvertimePay', "<class 'float'>", None, 54, 54, 0, True), ('OtherPay', "<class 'float'>", None, 54, 54, 0, True), ('Benefits', "<class 'float'>", None, 54, 54, 0, True), ('TotalPay', "<class 'float'>", None, 54, 54, 0, True), ('TotalPayBenefits', "<class 'float'>", None, 54, 54, 0, True), ('Year', "<class 'int'>", None, 10, 10, 0, True), ('Notes', "<class 'str'>", None, 65536, 65536, 0, True), ('Agency', "<class 'str'>", None, 65536, 65536, 0, True), ('Status', "<class 'str'>", None, 65536, 65536, 0, True))

# precisamos 1º de uma lista com o nome das colunas para poder organizar as colunas da nossa tabela:
# o nome das colunas está na variável descrição, dê uma olhada.

import pandas as pd

colunas = []
for tuplas in descricao:
    colunas.append(tuplas[0])
print(colunas)


# tabela = pd.DataFrame.from_records(informacoes)
# para acertar nossa tabela, vamos precisar fazer:
tabela = pd.DataFrame.from_records(informacoes, columns=colunas) # onde colunas é uma lista com o nome das colunas
display(tabela)


# além disso, precisamos enviar por e-mail para o RH uma lista com o nome e o cargo de cada pessoa da tabela 
# então você precisa construir o texto do corpo desse email do tipo:

# texto = """
# RH, segue a lista dos funcionários:
# Fulano, Cargo: tal
# Beltrano, Cargo: isso
# """
texto = 'RH, segue a lista de funcionários:'
# para cada item das nossas informações
#pegar o nome do funcionário -> tupla [1]
#pegar o cargo do funcionário -> tupla [2]
# adicionar uma nova linha no texto e adicionar fulana, cargo: tal 

for tupla in informacoes:
    nome_funcionario = tupla[1]
    cargo = tupla[2]
    texto = texto + f'\n{nome_funcionario}, Cargo: {cargo}'
print(texto)
# Out:
# ['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency', 'Status']
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
# ...

# %% [markdown]
# 3 - Extração dos links de Download de Vídeos do Vimeo
#
# - Precisamos pegar os links em 1080p, 720p e 540p para importar os vídeos para uma nova plataforma

# %%
# para pegar o dicionario do vimeo, use: # nesse caso para esse tipo de importação o arquivo a ser importado deve ser do tipo .py para que isso aconteça de forma correta.
from dic import dicionario_vimeo # Logo a inforamção a ser posta é  o nome do arquivo do dicionário e em segida o dicionário que se deseja importar, Lembrando que o mesmo deve também estar na mesma pasta do programa que voc~e está trabalhando.


# você precisa chegar em:
# videos = [
#     {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p},
# ]
print(dicionario_vimeo) #Aqui fizemos o print do dicionário vimeo com todas as informações que nós precisamos.
for chave in dicionario_vimeo: #percorremos o dicionário vimeo coletando todas as suas primeiras chaves. 
    print(chave) # Em seguida apresentamos todas elas
dados = dicionario_vimeo['data'] #Aqui nós pegamos do dicionário e a chave data e todas as informações da mesma, que na verdade é o que nos interessa. em seguida adicionamos essas informações a variável dados.
for chave in dados: # Agora percorrendo todos esses dados da chave data vamos apresentar essas chaves no print de baixo.
    print(chave)
# Out:
# {'total': 4510, 'page': 46, 'per_page': 100, 'paging': {'next': None, 'previous': '/users/64746254/videos?per_page=100&page=45', 'first': '/users/64746254/videos?per_page=100&page=1', 'last': '/users/64746254/videos?per_page=100&page=46'}, 'data': [{'uri': '/videos/210375279', 'name': 'Aula 2.3', 'description': None, 'type': 'video', 'link': 'https://vimeo.com/210375279', 'player_embed_url': 'https://player.vimeo.com/video/210375279?h=d8e5156450', 'duration': 160, 'width': 1364, 'language': None, 'height': 768, 'embed': {'html': '<iframe src="https://player.vimeo.com/video/210375279?h=d8e5156450&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=252054" width="1364" height="768" frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen title="Aula 2.3"></iframe>', 'badges': {'hdr': False, 'live': {'streaming': False, 'archived': False}, 'staff_pick': {'normal': False, 'best_of_the_month': False, 'best_of_the_year': False, 'premiere': False}, 'vod': False, '
# ...

# %%
# uma biblioteca que permite uma melhor exibição, inclusive, identando as informações do dicionário é o pprint, a mesma já é nativa do python e podemos fazer sua importação. Logo esse recuros é muito importante no momento de percorrer listas dentro do dicionário.

import pprint
informacoes =  dicionario_vimeo['data']
pprint.pprint(informacoes)
# Out:
# [{'app': None,
#   'categories': [],
#   'content_rating': ['unrated'],
#   'content_rating_class': 'unrated',
#   'created_time': '2017-03-28T04:17:04+00:00',
#   'description': None,
#   'download': [{'created_time': '2017-03-28T04:30:48+00:00',
#                 'expires': '2022-08-19T14:51:49+00:00',
#                 'fps': 24,
#                 'height': 720,
#                 'link': 'https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/8c89659d/aula_2.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=622e5e832382c2a1cb4b0902b3dda63ebc41b53668d65267840bd3aa2b10e096',
#                 'md5': 'd70993f6faf13cf8d8facaea20695c9e',
#                 'public_name': '720p',
#                 'quality': 'hd',
#                 'rendition': '720p',
#                 'size': 12618045,
#                 'size_short': '12.03MB',
#                 'type': 'video/mp4',
# ...

# %%
# para pegar o dicionario do vimeo, use:
from dic import dicionario_vimeo

import pprint

informacoes = dicionario_vimeo["data"] # Nesse caso nós pegamos a chave data dentro da biblioteca vimeo, e adicionamos a variavel informações.
videos = [] #Criamos a lista video que é onde nós adicionaremos as informações que nos interessa dentro da mesma.

for item in informacoes: #Com o for pegamos cada um dos itens dentro de informações.
    video_uri = item["uri"] #Adicionamos a variável video_uri item que tenha a chave uri que no caso a mesma tem como valor o código do vídeo.
    nome = item["name"] # Adicionamos a variável nome o valor da chave name dentro de cada item que contenha essa chave
    duracao = item["duration"]  # Adicionamos a variável duração o valor da chave duration dentro de cada item que contenha essa chave.


    link_540p = "" # Aqui criamos variáveis que irão receber os links de cada resolução.
    link_720p = ""
    link_1080p = ""

    lista_downloads = item["download"] #Agora pegamos a chave  download presente em item e adicionamos essas informações dentro da variável lista_downloads.
    for dicionario_download in lista_downloads: # A gora percorrendo a lista download, pegamos cada item de download e adicionamos a variável  dicionário_download.
        if dicionario_download["rendition"] == "540p": #Usando o if verificamos se dentro de cada um desses itens temos ualgum randition igual a 540p.
            link_540p = dicionario_download["link"] # se a resposta for positiva, o valor da chave link dnetro desse item será adicionada a variável link_540p e o mesmo irá valer para demais if que irão se suceder.
        if dicionario_download["rendition"] == "720p":
            link_720p = dicionario_download["link"]
        if dicionario_download["rendition"] == "1080p":
            link_1080p = dicionario_download["link"]
    
    dic_item = {'uri': video_uri, 'nome': nome, 'duracao': duracao, 'link540p': link_540p, 'link720p': link_720p, 'link1080p': link_1080p} # nesse momento criamos a variável dic_item, e dentro da mesma adicionamos todos os valores que conseguimos coletar com as linhas de código acima.
    videos.append(dic_item) #Com o append adicionamos as informações da tupla dic_item e adicionamos a mesma dentro da lista vídeos, que até então estava vazia.
pprint.pprint(videos) #Usando o pprint exibimos essas informações de forma mais organizada.

# você precisa chegar em:
# videos = [
#     {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p},
# ]
# Out:
# [{'duracao': 160,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/c103cec6/aula_2.3%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=359dd9db8ea5946c85acb4bf7b676012b00ded2abef9ee20d4af1be8141fa064',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/8c89659d/aula_2.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=622e5e832382c2a1cb4b0902b3dda63ebc41b53668d65267840bd3aa2b10e096',
#   'nome': 'Aula 2.3',
#   'uri': '/videos/210375279'},
#  {'duracao': 122,
#   'link1080p': '',
# ...

# %% [markdown]
# Crie um programa que analise um texto fornecido pelo usuário. O programa deve contar o número de palavras (independentemente se há repetição ou não), a quantidade de cada palavra e a quantidade de cada letra. Ignore maiúsculas e minúsculas ao contar letras (ou seja, transforme tudo para minúsculas). Faça o devido tratamento para pontuação e espaços ao contar palavras.
#
# O programa deve conter uma função chamada `analisar_texto` que recebe o texto como parâmetro e retorna a contagem de palavras, a frequência de palavras e a frequência de letras. A função deve ser devidamente documentada.
#
# Para o texto "Olá mundo! Este é um teste. Olá novamente." o programa deve imprimir:
#
# ```
# Contagem de palavras: 8
# Frequência de palavras: Counter({'Olá': 2, 'mundo': 1, 'Este': 1, 'é': 1, 'um': 1, 'teste': 1, 'novamente': 1})
# Frequência de letras: Counter({' ': 7, 'e': 6, 'o': 4, 't': 4, 'm': 3, 'n': 3, 'l': 2, 'á': 2, 'u': 2, 's': 2, 'd': 1, 'é': 1, 'v': 1, 'a': 1})
# ```
#
# Dica: use o módulo `string` para obter uma lista de caracteres de pontuação. Exemplo:
#
# ```python
# import string  # Essa é uma biblioteca dentro do próprio python onde a mesma auxilia no tratamento de pontuações da sua istring.
#
# print(string.punctuation)
# ```
#
# Dica: use o módulo `collections` para obter um contador de palavras e letras. Exemplo:
#
# ```python
# from collections import Counter # outra biblioteca é a biblioteca collections e sua classe counter para constução de frequências de palavras  e também letras
# print(Counter(['a', 'b', 'a', 'c', 'b', 'a']))
# print(Counter('abacba'))
# ```

# %%
#Dentro desse módulo string nós temso o que chamamos de constants que nos permitem trabalhar com todos os tipos de caracters de texto. ciando coleções.

import string 
print(string.punctuation) # Perceba que nessa saída obteremos uma coleção de pontuações.
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print(string.ascii_letters)#Aqui  temos todas as letras do A ao Z do minúsculo e também do minúsculo.
print(string.ascii_lowercase) #Aqui temos uma coleção com  as letras minúsculas
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# abcdefghijklmnopqrstuvwxyz

# %%
from collections import Counter 
print(Counter(['a', 'b', 'a', 'c', 'b', 'a'])) #independente se for passado para o colation uma lista ou uma string, o mesmo vai ler essas informações da mesma forma sempre como se os mesmos fossem sequências a serem analizadas
print(Counter('abacba'))
# Out:
# Counter({'a': 3, 'b': 2, 'c': 1})
# Counter({'a': 3, 'b': 2, 'c': 1})

# %%
#solução simples para começarmos

def analizar_texto(texto):
    palavras = texto.split() #como a função split conseguimos separar por padrão considerando os espaços. levando em consideração até mesmo as pontuações.
    contagem_palavras = len(palavras)
    frequencia_palavras = Counter(palavras)
    frequencia_letras = Counter(texto)

    return contagem_palavras, frequencia_palavras, frequencia_letras

contagem_palavras, frequencia_palavras, frequencia_letras = analizar_texto(texto)

texto = "Olá mundo! Este é um teste. Olá novamente."

print("Contagem de palavras {}".format(contagem_palavras))
print("Contagem de frequência de  palavras {}".format(frequencia_palavras))
print("Contagem de frequência de letras na palavra {}".format(frequencia_letras))
# Out:
# Contagem de palavras 8
# Contagem de frequência de  palavras Counter({'Olá': 2, 'mundo!': 1, 'Este': 1, 'é': 1, 'um': 1, 'teste.': 1, 'novamente.': 1})
# Contagem de frequência de letras na palavra Counter({' ': 7, 'e': 5, 't': 4, 'm': 3, 'n': 3, 'O': 2, 'l': 2, 'á': 2, 'u': 2, 'o': 2, 's': 2, '.': 2, 'd': 1, '!': 1, 'E': 1, 'é': 1, 'v': 1, 'a': 1})

# %% [markdown]
# ### Antes de tudo vamos entender uma situação em específico que pode nos ajudar nos próximos passos.

# %%
vogais = "aeiou"
numeros = '12345'
removo = "a"

guia_troca = str.maketrans(vogais, numeros, removo) #esse recurso do transforma determinado valor em outro, para esse caso estamos transformando as vogais em numeros  como ultimo parametro passado nós temos o que iremos remover, que no caso será a vogal a.

print(guia_troca) # O resultado obtido será a informaão dos valores que deverão ser trocados e ou quem esta sendo removido. essa informação é tida de forma numérica pois é a linguagem que o computuador entende ou seja cada vavor significa um caracter segundo a tabela de interpretação da própia máquina.

# Vamos pegar uma coleção de letras minúsculas:
letras_minusculas = string.ascii_lowercase

# pegaremos o nosso guia troca, e usaremos o mesmo para realizar essa troca dentro da nossa coleção letras_minúsculas usando o trasnlate, que no caso é outro recurso do python, assim será possível ver como resultado do mesmo as trocas e remoções dentro da coleção.

print(letras_minusculas.translate(guia_troca))
# Out:
# {97: None, 101: 50, 105: 51, 111: 52, 117: 53}
# bcd2fgh3jklmn4pqrst5vwxyz

# %%
# Agora voltemos ao exercício. 

def analizar_texto(texto):

    tratamento = str.maketrans('', '', string.punctuation) # como o maketrasn indicamos o que desejamos remover, que no caso são todas as pontuações dentro do texto para que o mesmo não as apresente no momento da contagem, e jogamos essa informação para a variável tratamento.

    texto_tratado = texto.translate(tratamento) # Agora usamos o translate para efetivamente fazer essa reemoção dentro do texto, em seguida jogamos o texto como essas remoções detro da variável texto_tratado e executamos novamente os códigos abaixo.

    palavras = texto_tratado.split()
    contagem_palavras = len(palavras)
    frequencia_palavras = Counter(palavras)
    frequencia_letras = Counter(texto_tratado.lower()) # Para que a contagem de letras não aconteça de forma separada em maiúsculas e minúsculas, com o lower() transformamos o  

    return contagem_palavras, frequencia_palavras, frequencia_letras

contagem_palavras, frequencia_palavras, frequencia_letras = analizar_texto(texto)

texto = "Olá mundo! Este é um teste. Olá novamente."

print("Contagem de palavras {}".format(contagem_palavras))
print("Contagem de frequência de  palavras {}".format(frequencia_palavras)) # Perceba que nessa saída, agora as pontuações estão removidas. no caso o ponto de exclamação e os pontos finais dentro do texto.
print("Contagem de frequência de letras na palavra {}".format(frequencia_letras))
# Out:
# Contagem de palavras 8
# Contagem de frequência de  palavras Counter({'Olá': 2, 'mundo': 1, 'Este': 1, 'é': 1, 'um': 1, 'teste': 1, 'novamente': 1})
# Contagem de frequência de letras na palavra Counter({' ': 7, 'e': 6, 'o': 4, 't': 4, 'm': 3, 'n': 3, 'l': 2, 'á': 2, 'u': 2, 's': 2, 'd': 1, 'é': 1, 'v': 1, 'a': 1})

# %% [markdown]
# ### Agora veremos como documentar essa funçção, lembrando qeu o que é tido no matérial são códigos comentados e não documentados. A documentação deve ser mais direta e sucinta.

# %%
#dicumentação

def analizar_texto(texto):
    """
    Analiza o texto fornecido e calcula a contagem de palavras, a frequência de palavras e a frequência de letras.

    Parâmetros
    ............
    texto: str 
        texto a ser analizado

    retornos
    ............
    tupla
        Contagem de palavras, frequência de palavras e a frequência de letras.
    """

    tratamento = str.maketrans('', '', string.punctuation)

    texto_tratado = texto.translate(tratamento)
    palavras = texto_tratado.split()
    contagem_palavras = len(palavras)
    frequencia_palavras = Counter(palavras)
    frequencia_letras = Counter(texto_tratado.lower())  

    return contagem_palavras, frequencia_palavras, frequencia_letras

contagem_palavras, frequencia_palavras, frequencia_letras = analizar_texto(texto)

texto = "Olá mundo! Este é um teste. Olá novamente."

print("Contagem de palavras {}".format(contagem_palavras))
print("Contagem de frequência de  palavras {}".format(frequencia_palavras))
print("Contagem de frequência de letras na palavra {}".format(frequencia_letras))

# %% [markdown]
# Escreva um programa que gere uma senha aleatória com um determinado comprimento. A senha deve conter uma mistura de letras, números e caracteres especiais. O comprimento da senha deve ser fornecido pelo usuário. Se o comprimento for menor que 4, imprima uma mensagem de erro e peça ao usuário para fornecer um novo comprimento.
#
# A senha deve ser aleatória, então cada vez que o usuário executar o programa, uma nova senha deve ser gerada. Obrigatoriamente, a senha deve conter pelo menos uma letra, um número e um caractere especial. A senha não pode conter espaços em branco.
#
# O programa deve conter uma função chamada `gerar_senha` que recebe o comprimento da senha como parâmetro e retorna a senha gerada. Se o comprimento for inválido, a função deve retornar None.
#
# Exemplo de saída:
#
# ```
# Digite o comprimento da senha: 10
# 8Zn$*2q9X
# ```
#
# - Dica: use a biblioteca random e a função shuffle para embaralhar os caracteres da senha.
# - Dica: use a função choice, dessa mesma biblioteca, para escolher um caractere aleatório de uma string.
# - Dica: use a biblioteca string para obter uma lista de caracteres válidos para a senha.

# %%
import string 

print(string.ascii_letters) #Como bem já sabemos, esse código nos apresenta uma coleção de letras do alfabeto, tanto de minúsculas como de maiúsculas.
print(string.digits)# Nesse caso uma coleção de números do zero ao nove 
print(string.punctuation) # Aqui, uma coleção com todos os sinais de pontuação
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
import random
random.choice(string.digits) # Com o choice podemos pedir que sesja apresentado nesse caso um número aleatóriamente toda a vez que o código é rodado.
# Out:
# '5'

# %%
random.choices(string.digits, k=3) # nesse caso aqui pedimos novamente que os  números sejam apresentados de forma aleatória e com o k=3 dizemos ao interpretador que dessa vez será com 3 dígitos.
# Out:
# ['3', '8', '7']

# %%
escolhas = random.choices(string.digits, k=5)
print(escolhas)
# Out:
# ['2', '5', '3', '2', '0']

# %%
random.shuffle(escolhas)# O shuffle nesse caso serve para embaralhar a sequência que obtivemos. Os valores se preservam porém a ordem deles irá mudar.
print(escolhas)
# Out:
# ['8', '7', '9', '6', '3']

# %%
def gerar_senha(tamaho):
    if tamanho < 4:
        print("O cumprimento deve ser de pelomenos 4 digitos")
    else:
        senha = [ #Nesse caso nós criamos uma lista, onde a mesma trará em seu interior, uma pntuação, uma letra e um número.
            random.choice(string.digits),
            random.choice(string.ascii_letters),
            random.choice(string.punctuation)
        ]
        random.shuffle(senha) # Com o shuffle embaralhamos essa senha 
        return "-".join(senha) #Com o join nós tranformamos a lista em string. O Join também permitee juntar os valores da string de diversas formas, seja como uma vírgula a exemplo, um ponto uma barra. logo o mesmo também traz essa possibilidade.

    

tamanho =  int(input("Digite o comprimento da senha: "))
print(gerar_senha(tamanho))
# Out:
# 3-N-'
